# %%
import pandas as pd
import geopandas as gpd
from shapely.ops import unary_union

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# # PAM - Produção Agrícola Municipal

# %% [markdown]
# ## Café

# %% [markdown]
# ### Área x UF

# %%
pam_cafe = pd.read_csv('../data/pam/output/cafe/pam_cafe.csv')

# %%
geodata_uf = gpd.read_file('../data/gis-dataset-brasil/uf/shapefile/uf.shp')

# %%
geodata_uf.head()
# Out:
#   UF_05                                MICRO                 MESO    REGIAO  \
# 0    AC                            BRASILEIA         VALE DO ACRE     Norte
# 1    AL  ALAGOANA DO SERTAO DO SAO FRANCISCO     AGRESTE ALAGOANO  Nordeste
# 2    AM                        ALTO SOLIMOES    CENTRO AMAZONENSE     Norte
# 3    AP                                AMAPA       NORTE DO AMAPA     Norte
# 4    BA                           ALAGOINHAS  CENTRO NORTE BAIANO  Nordeste
#
#     NOME_UF GEOCODIGO                                           geometry
# 0      Acre        12  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...
# 1   Alagoas        27  POLYGON ((-38.23724 -9.32937, -38.20273 -9.296...
# 2  Amazonas        13  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 3     Amapá        16  POLYGON ((-54.87178 2.43408, -54.79692 2.43935...
# 4     Bahia        29  POLYGON ((-46.60921 -11.25550, -46.58164 -11.2...

# %%
pam_cafe.head()
# Out:
#    CODIGO_UF        UF  CODIGO_MUNICIPIO              MUNICIPIO   ANO  \
# 0         11  Rondônia           1100015  Alta Floresta D'Oeste  1974
# 1         11  Rondônia           1100015  Alta Floresta D'Oeste  1975
# 2         11  Rondônia           1100015  Alta Floresta D'Oeste  1976
# 3         11  Rondônia           1100015  Alta Floresta D'Oeste  1977
# 4         11  Rondônia           1100015  Alta Floresta D'Oeste  1978
#
#    MOEDA_VIGENTE  AREA_PLANTADA  AREA_PLANTADA_PERC  AREA_COLHIDA  \
# 0  Mil Cruzeiros            NaN                 NaN           NaN
# 1  Mil Cruzeiros            NaN                 NaN           NaN
# 2  Mil Cruzeiros            NaN                 NaN           NaN
# 3  Mil Cruzeiros            NaN                 NaN           NaN
# 4  Mil Cruzeiros            NaN                 NaN           NaN
#
#    AREA_COLHIDA_PERC  QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  \
# 0                NaN                   NaN                      NaN
# 1                NaN                   NaN                      NaN
# 2                NaN                   NaN                      NaN
# 3                NaN                   NaN                      NaN
# 4                NaN                   NaN                      NaN
#
#    VALOR_PRODUCAO  VALOR_PRODUCAO_PERC
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN                  NaN
# 4             NaN                  NaN

# %%
pam_cafe_uf = pam_cafe.groupby(['UF', 'ANO']).aggregate(sum).reset_index()[['UF', 'ANO', 'AREA_PLANTADA', 'QUANTIDADE_PRODUZIDA', 'RENDIMENTO_MED_PRODUCAO', 'VALOR_PRODUCAO']]
pam_cafe_uf = pam_cafe_uf[pam_cafe_uf['ANO'] >= 1990]
pam_cafe_uf.rename(columns={'UF':'NOME_UF'}, inplace=True)
pam_cafe_geo_uf = geodata_uf.merge(pam_cafe_uf, on='NOME_UF')
# Out:
# /tmp/ipykernel_15205/4188203090.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pam_cafe_uf = pam_cafe.groupby(['UF', 'ANO']).aggregate(sum).reset_index()[['UF', 'ANO', 'AREA_PLANTADA', 'QUANTIDADE_PRODUZIDA', 'RENDIMENTO_MED_PRODUCAO', 'VALOR_PRODUCAO']]

# %%
pam_cafe_geo_uf
# Out:
#     UF_05      MICRO                    MESO REGIAO    NOME_UF GEOCODIGO  \
# 0      AC  BRASILEIA            VALE DO ACRE  Norte       Acre        12
# 1      AC  BRASILEIA            VALE DO ACRE  Norte       Acre        12
# 2      AC  BRASILEIA            VALE DO ACRE  Norte       Acre        12
# 3      AC  BRASILEIA            VALE DO ACRE  Norte       Acre        12
# 4      AC  BRASILEIA            VALE DO ACRE  Norte       Acre        12
# ..    ...        ...                     ...    ...        ...       ...
# 801    TO  ARAGUAINA  OCIDENTAL DO TOCANTINS  Norte  Tocantins        17
# 802    TO  ARAGUAINA  OCIDENTAL DO TOCANTINS  Norte  Tocantins        17
# 803    TO  ARAGUAINA  OCIDENTAL DO TOCANTINS  Norte  Tocantins        17
# 804    TO  ARAGUAINA  OCIDENTAL DO TOCANTINS  Norte  Tocantins        17
# 805    TO  ARAGUAINA  OCIDENTAL DO TOCANTINS  Norte  Tocantins        17
#
#                                               geometry   ANO  AREA_PLANTADA  \
# 0    POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1990          965.0
# 1    POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1991          904.0
# 2    POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1992          845.0
# 3    POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1993          861.0
# 4    POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1994          841.0
# ..                                                 ...   ...            ...
# 801  POLYGON ((-50.69824 -11.31014, -50.69636 -11.3...  2016            0.0
# 802  POLYGON ((-50.69824 -11.31014, -50.69636 -11.3...  2017            0.0
# 803  POLYGON ((-50.69824 -11.31014, -50.69636 -11.3...  2018            0.0
# 804  POLYGON ((-50.69824 -11.31014, -50.69636 -11.3...  2019            0.0
# 805  POLYGON ((-50.69824 -11.31014, -50.69636 -11.3...  2020            0.0
#
#      QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  VALOR_PRODUCAO
# 0                   959.0                   9626.0         20651.0
# 1                   808.0                   8925.0         66988.0
# 2                   780.0                   8721.0       1289839.0
# 3                   823.0                  14350.0         45601.0
# 4                   792.0                  14521.0           445.0
# ..                    ...                      ...             ...
# 801                   0.0                      0.0             0.0
# 802                   0.0                      0.0             0.0
# 803                   0.0                      0.0             0.0
# 804                   0.0                      0.0             0.0
# 805                   0.0                      0.0             0.0
#
# [806 rows x 12 columns]

# %%
pam_cafe_geo_uf.to_file("../data/pam/output/cafe/pam_cafe_geo_uf.geojson", driver='GeoJSON')

# %% [markdown]
# ### Área x Município

# %%
geodata_mun = gpd.read_file('../data/gis-dataset-brasil/municipio/shapefile/Munic.shp')

# %%
pam_cafe.head()
# Out:
#    CODIGO_UF        UF  CODIGO_MUNICIPIO              MUNICIPIO   ANO  \
# 0         11  Rondônia           1100015  Alta Floresta D'Oeste  1974
# 1         11  Rondônia           1100015  Alta Floresta D'Oeste  1975
# 2         11  Rondônia           1100015  Alta Floresta D'Oeste  1976
# 3         11  Rondônia           1100015  Alta Floresta D'Oeste  1977
# 4         11  Rondônia           1100015  Alta Floresta D'Oeste  1978
#
#    MOEDA_VIGENTE  AREA_PLANTADA  AREA_PLANTADA_PERC  AREA_COLHIDA  \
# 0  Mil Cruzeiros            NaN                 NaN           NaN
# 1  Mil Cruzeiros            NaN                 NaN           NaN
# 2  Mil Cruzeiros            NaN                 NaN           NaN
# 3  Mil Cruzeiros            NaN                 NaN           NaN
# 4  Mil Cruzeiros            NaN                 NaN           NaN
#
#    AREA_COLHIDA_PERC  QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  \
# 0                NaN                   NaN                      NaN
# 1                NaN                   NaN                      NaN
# 2                NaN                   NaN                      NaN
# 3                NaN                   NaN                      NaN
# 4                NaN                   NaN                      NaN
#
#    VALOR_PRODUCAO  VALOR_PRODUCAO_PERC
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN                  NaN
# 4             NaN                  NaN

# %%
geodata_mun.head()
# Out:
#    GEOCODIGO              NOME  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
# 2    1301654           Guajará  AM     13  Norte  SUDOESTE AMAZONENSE
# 3    1200427   Rodrigues Alves  AC     12  Norte        VALE DO JURUA
# 4    1200203   Cruzeiro do Sul  AC     12  Norte        VALE DO JURUA
#
#         MICROREGIA LATITUDE LONGITUDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896
# 1    ALTO SOLIMOES   -4.372   -70.192
# 2            JURUA   -7.546   -72.584
# 3  CRUZEIRO DO SUL   -7.742   -72.647
# 4  CRUZEIRO DO SUL   -7.631    -72.67
#
#                                             geometry
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 2  POLYGON ((-73.73762 -7.13432, -73.70822 -7.040...
# 3  POLYGON ((-73.69158 -7.76778, -73.67485 -7.740...
# 4  POLYGON ((-73.62958 -8.05086, -73.42396 -8.032...

# %%
pam_cafe.rename(columns={'MUNICIPIO':'NOME', 'CODIGO_MUNICIPIO':'GEOCODIGO'}, inplace=True)
pam_cafe_geo_mun = geodata_mun.merge(pam_cafe, on='GEOCODIGO')
pam_cafe_geo_mun = pam_cafe_geo_mun.drop(['UF_y', 'NOME_y', 'CODIGO_UF'], axis=1).rename(columns={'NOME_x':'MUNICIPIO', 'UF_x':'UF'})

# %%
pam_cafe_geo_mun.head()
# Out:
#    GEOCODIGO    MUNICIPIO  UF  ID_UF REGIAO     MESOREGIAO       MICROREGIA  \
# 0    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 1    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 2    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 3    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 4    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
#
#   LATITUDE LONGITUDE                                           geometry   ANO  \
# 0   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1974
# 1   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1975
# 2   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1976
# 3   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1977
# 4   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1978
#
#    MOEDA_VIGENTE  AREA_PLANTADA  AREA_PLANTADA_PERC  AREA_COLHIDA  \
# 0  Mil Cruzeiros            NaN                 NaN           NaN
# 1  Mil Cruzeiros            NaN                 NaN           NaN
# 2  Mil Cruzeiros            NaN                 NaN           NaN
# 3  Mil Cruzeiros            NaN                 NaN           8.0
# 4  Mil Cruzeiros            NaN                 NaN           9.0
#
#    AREA_COLHIDA_PERC  QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  \
# 0                NaN                   NaN                      NaN
# 1                NaN                   NaN                      NaN
# 2                NaN                   NaN                      NaN
# 3               0.68                   4.0                    500.0
# 4               0.75                   4.0                    444.0
#
#    VALOR_PRODUCAO  VALOR_PRODUCAO_PERC
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3            60.0                 0.58
# 4            68.0                 0.91

# %%
ufs = pam_cafe_geo_mun['UF'].unique().tolist()

# %%
for uf in ufs:
    df = pam_cafe_geo_mun[pam_cafe_geo_mun['UF'] == uf]
    df.to_file(f"../data/pam/output/cafe/pam_geo_ufs/pam_cafe_geo_{uf}.geojson", driver='GeoJSON')

# %% [markdown]
# ### Área x Município - Diferença 1990-2020

# %%
pam_cafe_diff = pd.read_csv('../data/pam/output/cafe/pam_cafe_diff.csv')

# %%
pam_cafe_diff.head()
# Out:
#    CODIGO_UF        UF  GEOCODIGO                   NOME  AREA_1990  AREA_2020
# 0         11  Rondônia    1100015  Alta Floresta D'Oeste      11.85      54.99
# 1         11  Rondônia    1100023              Ariquemes      41.65       2.25
# 2         11  Rondônia    1100031                 Cabixi       2.99       0.06
# 3         11  Rondônia    1100049                 Cacoal      45.58      63.44
# 4         11  Rondônia    1100056             Cerejeiras       5.82       0.06

# %%
geodata_mun.head()
# Out:
#    GEOCODIGO              NOME  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
# 2    1301654           Guajará  AM     13  Norte  SUDOESTE AMAZONENSE
# 3    1200427   Rodrigues Alves  AC     12  Norte        VALE DO JURUA
# 4    1200203   Cruzeiro do Sul  AC     12  Norte        VALE DO JURUA
#
#         MICROREGIA LATITUDE LONGITUDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896
# 1    ALTO SOLIMOES   -4.372   -70.192
# 2            JURUA   -7.546   -72.584
# 3  CRUZEIRO DO SUL   -7.742   -72.647
# 4  CRUZEIRO DO SUL   -7.631    -72.67
#
#                                             geometry
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 2  POLYGON ((-73.73762 -7.13432, -73.70822 -7.040...
# 3  POLYGON ((-73.69158 -7.76778, -73.67485 -7.740...
# 4  POLYGON ((-73.62958 -8.05086, -73.42396 -8.032...

# %%
pam_cafe_diff.rename(columns={'MUNICIPIO':'NOME', 'CODIGO_MUNICIPIO':'GEOCODIGO'}, inplace=True)
pam_cafe_diff_geo_mun = geodata_mun.merge(pam_cafe_diff, on='GEOCODIGO')
pam_cafe_diff_geo_mun = pam_cafe_diff_geo_mun.drop(['UF_y', 'NOME_y', 'CODIGO_UF'], axis=1).rename(columns={'NOME_x':'MUNICIPIO', 'UF_x':'UF'})

# %%
pam_cafe_diff_geo_mun.head()
# Out:
#    GEOCODIGO         MUNICIPIO  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
# 2    1301654           Guajará  AM     13  Norte  SUDOESTE AMAZONENSE
# 3    1200427   Rodrigues Alves  AC     12  Norte        VALE DO JURUA
# 4    1200203   Cruzeiro do Sul  AC     12  Norte        VALE DO JURUA
#
#         MICROREGIA LATITUDE LONGITUDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896
# 1    ALTO SOLIMOES   -4.372   -70.192
# 2            JURUA   -7.546   -72.584
# 3  CRUZEIRO DO SUL   -7.742   -72.647
# 4  CRUZEIRO DO SUL   -7.631    -72.67
#
#                                             geometry  AREA_1990  AREA_2020
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...       0.22        NaN
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...        NaN        NaN
# 2  POLYGON ((-73.73762 -7.13432, -73.70822 -7.040...        NaN        NaN
# 3  POLYGON ((-73.69158 -7.76778, -73.67485 -7.740...        NaN        NaN
# 4  POLYGON ((-73.62958 -8.05086, -73.42396 -8.032...       0.51        NaN

# %%
pam_cafe_diff_geo_sp = pam_cafe_diff_geo_mun[pam_cafe_diff_geo_mun['UF'] == 'SP']
pam_cafe_diff_geo_sp.to_file("../data/pam/output/cafe/pam_cafe_diff_geo_sp.geojson", driver='GeoJSON')

# %% [markdown]
# ## Cana-de-Açúcar

# %% [markdown]
# ### Área x UF

# %%
pam_cana = pd.read_csv('../data/pam/output/cana/pam_cana.csv')

# %%
geodata_uf.head()
# Out:
#   UF_05                                MICRO                 MESO    REGIAO  \
# 0    AC                            BRASILEIA         VALE DO ACRE     Norte
# 1    AL  ALAGOANA DO SERTAO DO SAO FRANCISCO     AGRESTE ALAGOANO  Nordeste
# 2    AM                        ALTO SOLIMOES    CENTRO AMAZONENSE     Norte
# 3    AP                                AMAPA       NORTE DO AMAPA     Norte
# 4    BA                           ALAGOINHAS  CENTRO NORTE BAIANO  Nordeste
#
#     NOME_UF GEOCODIGO                                           geometry
# 0      Acre        12  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...
# 1   Alagoas        27  POLYGON ((-38.23724 -9.32937, -38.20273 -9.296...
# 2  Amazonas        13  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 3     Amapá        16  POLYGON ((-54.87178 2.43408, -54.79692 2.43935...
# 4     Bahia        29  POLYGON ((-46.60921 -11.25550, -46.58164 -11.2...

# %%
pam_cana.head()
# Out:
#    CODIGO_UF        UF  CODIGO_MUNICIPIO              MUNICIPIO   ANO  \
# 0         11  Rondônia           1100015  Alta Floresta D'Oeste  1974
# 1         11  Rondônia           1100015  Alta Floresta D'Oeste  1975
# 2         11  Rondônia           1100015  Alta Floresta D'Oeste  1976
# 3         11  Rondônia           1100015  Alta Floresta D'Oeste  1977
# 4         11  Rondônia           1100015  Alta Floresta D'Oeste  1978
#
#    MOEDA_VIGENTE  AREA_PLANTADA  AREA_PLANTADA_PERC  AREA_COLHIDA  \
# 0  Mil Cruzeiros            NaN                 NaN           NaN
# 1  Mil Cruzeiros            NaN                 NaN           NaN
# 2  Mil Cruzeiros            NaN                 NaN           NaN
# 3  Mil Cruzeiros            NaN                 NaN           NaN
# 4  Mil Cruzeiros            NaN                 NaN           NaN
#
#    AREA_COLHIDA_PERC  QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  \
# 0                NaN                   NaN                      NaN
# 1                NaN                   NaN                      NaN
# 2                NaN                   NaN                      NaN
# 3                NaN                   NaN                      NaN
# 4                NaN                   NaN                      NaN
#
#    VALOR_PRODUCAO  VALOR_PRODUCAO_PERC
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN                  NaN
# 4             NaN                  NaN

# %%
pam_cana_uf = pam_cana.groupby(['UF', 'ANO']).aggregate(sum).reset_index()[['UF', 'ANO', 'AREA_PLANTADA', 'QUANTIDADE_PRODUZIDA', 'RENDIMENTO_MED_PRODUCAO', 'VALOR_PRODUCAO']]
pam_cana_uf = pam_cana_uf[pam_cana_uf['ANO'] >= 1990]
pam_cana_uf.rename(columns={'CODIGO_UF':'GEOCODIGO', 'UF' : 'NOME_UF'}, inplace=True)
pam_cana_geo_uf = geodata_uf.merge(pam_cana_uf, on='NOME_UF')
# Out:
# /tmp/ipykernel_11715/668353926.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   pam_cana_uf = pam_cana.groupby(['UF', 'ANO']).aggregate(sum).reset_index()[['UF', 'ANO', 'AREA_PLANTADA', 'QUANTIDADE_PRODUZIDA', 'RENDIMENTO_MED_PRODUCAO', 'VALOR_PRODUCAO']]

# %%
pam_cana_geo_uf.head()
# Out:
#   UF_05      MICRO          MESO REGIAO NOME_UF GEOCODIGO  \
# 0    AC  BRASILEIA  VALE DO ACRE  Norte    Acre        12
# 1    AC  BRASILEIA  VALE DO ACRE  Norte    Acre        12
# 2    AC  BRASILEIA  VALE DO ACRE  Norte    Acre        12
# 3    AC  BRASILEIA  VALE DO ACRE  Norte    Acre        12
# 4    AC  BRASILEIA  VALE DO ACRE  Norte    Acre        12
#
#                                             geometry   ANO  AREA_PLANTADA  \
# 0  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1990         1538.0
# 1  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1991          654.0
# 2  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1992          617.0
# 3  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1993          711.0
# 4  POLYGON ((-73.80098 -7.11146, -73.73763 -7.134...  1994          668.0
#
#    QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  VALOR_PRODUCAO
# 0               17275.0                 270500.0         33593.0
# 1               15179.0                 250500.0        228705.0
# 2               13913.0                 230577.0        670749.0
# 3               18861.0                 644050.0         44574.0
# 4               17419.0                 548166.0          1552.0

# %%
pam_cana_geo_uf.to_file("../data/pam/output/cana/pam_cana_geo_uf.geojson", driver='GeoJSON')

# %% [markdown]
# ### Área x Município

# %%
pam_cana.head()
# Out:
#    CODIGO_UF        UF  CODIGO_MUNICIPIO              MUNICIPIO   ANO  \
# 0         11  Rondônia           1100015  Alta Floresta D'Oeste  1974
# 1         11  Rondônia           1100015  Alta Floresta D'Oeste  1975
# 2         11  Rondônia           1100015  Alta Floresta D'Oeste  1976
# 3         11  Rondônia           1100015  Alta Floresta D'Oeste  1977
# 4         11  Rondônia           1100015  Alta Floresta D'Oeste  1978
#
#    MOEDA_VIGENTE  AREA_PLANTADA  AREA_PLANTADA_PERC  AREA_COLHIDA  \
# 0  Mil Cruzeiros            NaN                 NaN           NaN
# 1  Mil Cruzeiros            NaN                 NaN           NaN
# 2  Mil Cruzeiros            NaN                 NaN           NaN
# 3  Mil Cruzeiros            NaN                 NaN           NaN
# 4  Mil Cruzeiros            NaN                 NaN           NaN
#
#    AREA_COLHIDA_PERC  QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  \
# 0                NaN                   NaN                      NaN
# 1                NaN                   NaN                      NaN
# 2                NaN                   NaN                      NaN
# 3                NaN                   NaN                      NaN
# 4                NaN                   NaN                      NaN
#
#    VALOR_PRODUCAO  VALOR_PRODUCAO_PERC
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN                  NaN
# 4             NaN                  NaN

# %%
geodata_mun.head()
# Out:
#    GEOCODIGO              NOME  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
# 2    1301654           Guajará  AM     13  Norte  SUDOESTE AMAZONENSE
# 3    1200427   Rodrigues Alves  AC     12  Norte        VALE DO JURUA
# 4    1200203   Cruzeiro do Sul  AC     12  Norte        VALE DO JURUA
#
#         MICROREGIA LATITUDE LONGITUDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896
# 1    ALTO SOLIMOES   -4.372   -70.192
# 2            JURUA   -7.546   -72.584
# 3  CRUZEIRO DO SUL   -7.742   -72.647
# 4  CRUZEIRO DO SUL   -7.631    -72.67
#
#                                             geometry
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 2  POLYGON ((-73.73762 -7.13432, -73.70822 -7.040...
# 3  POLYGON ((-73.69158 -7.76778, -73.67485 -7.740...
# 4  POLYGON ((-73.62958 -8.05086, -73.42396 -8.032...

# %%
pam_cana.rename(columns={'MUNICIPIO':'NOME', 'CODIGO_MUNICIPIO':'GEOCODIGO'}, inplace=True)
pam_cana_geo_mun = geodata_mun.merge(pam_cana, on='GEOCODIGO')
pam_cana_geo_mun = pam_cana_geo_mun.drop(['UF_y', 'NOME_y', 'CODIGO_UF'], axis=1).rename(columns={'NOME_x':'MUNICIPIO', 'UF_x':'UF'})

# %%
pam_cana_geo_mun.head()
# Out:
#    GEOCODIGO    MUNICIPIO  UF  ID_UF REGIAO     MESOREGIAO       MICROREGIA  \
# 0    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 1    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 2    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 3    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
# 4    1200336  Mâncio Lima  AC     12  Norte  VALE DO JURUA  CRUZEIRO DO SUL
#
#   LATITUDE LONGITUDE                                           geometry   ANO  \
# 0   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1974
# 1   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1975
# 2   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1976
# 3   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1977
# 4   -7.614   -72.896  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...  1978
#
#    MOEDA_VIGENTE  AREA_PLANTADA  AREA_PLANTADA_PERC  AREA_COLHIDA  \
# 0  Mil Cruzeiros            NaN                 NaN           NaN
# 1  Mil Cruzeiros            NaN                 NaN           NaN
# 2  Mil Cruzeiros            NaN                 NaN           NaN
# 3  Mil Cruzeiros            NaN                 NaN          44.0
# 4  Mil Cruzeiros            NaN                 NaN          35.0
#
#    AREA_COLHIDA_PERC  QUANTIDADE_PRODUZIDA  RENDIMENTO_MED_PRODUCAO  \
# 0                NaN                   NaN                      NaN
# 1                NaN                   NaN                      NaN
# 2                NaN                   NaN                      NaN
# 3               3.73                1100.0                  25000.0
# 4               2.90                 875.0                  25000.0
#
#    VALOR_PRODUCAO  VALOR_PRODUCAO_PERC
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3           187.0                 1.80
# 4           201.0                 2.68

# %%
pam_cana_geo_sp = pam_cana_geo_mun[pam_cana_geo_mun['UF'] == 'SP']
pam_cana_geo_sp.to_file("../data/pam/output/cana/pam_cana_geo_sp.geojson", driver='GeoJSON')

# %% [markdown]
# ### Área x Município - Diferença 1990-2020

# %%
pam_cana_diff = pd.read_csv('../data/pam/output/cana/pam_cana_diff.csv')

# %%
pam_cana_diff.head()
# Out:
#    CODIGO_UF        UF  CODIGO_MUNICIPIO              MUNICIPIO  AREA_1990  \
# 0         11  Rondônia           1100015  Alta Floresta D'Oeste        NaN
# 1         11  Rondônia           1100023              Ariquemes       0.27
# 2         11  Rondônia           1100031                 Cabixi        NaN
# 3         11  Rondônia           1100049                 Cacoal        NaN
# 4         11  Rondônia           1100056             Cerejeiras        NaN
#
#    AREA_2020
# 0       0.04
# 1       0.17
# 2       0.15
# 3       0.14
# 4       0.14

# %%
geodata_mun.head()
# Out:
#    GEOCODIGO              NOME  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
# 2    1301654           Guajará  AM     13  Norte  SUDOESTE AMAZONENSE
# 3    1200427   Rodrigues Alves  AC     12  Norte        VALE DO JURUA
# 4    1200203   Cruzeiro do Sul  AC     12  Norte        VALE DO JURUA
#
#         MICROREGIA LATITUDE LONGITUDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896
# 1    ALTO SOLIMOES   -4.372   -70.192
# 2            JURUA   -7.546   -72.584
# 3  CRUZEIRO DO SUL   -7.742   -72.647
# 4  CRUZEIRO DO SUL   -7.631    -72.67
#
#                                             geometry
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 2  POLYGON ((-73.73762 -7.13432, -73.70822 -7.040...
# 3  POLYGON ((-73.69158 -7.76778, -73.67485 -7.740...
# 4  POLYGON ((-73.62958 -8.05086, -73.42396 -8.032...

# %%
pam_cana_diff.rename(columns={'MUNICIPIO':'NOME', 'CODIGO_MUNICIPIO':'GEOCODIGO'}, inplace=True)
pam_cana_diff_geo_mun = geodata_mun.merge(pam_cana_diff, on='GEOCODIGO')
pam_cana_diff_geo_mun = pam_cana_diff_geo_mun.drop(['UF_y', 'NOME_y', 'CODIGO_UF'], axis=1).rename(columns={'NOME_x':'MUNICIPIO', 'UF_x':'UF'})

# %%
pam_cana_diff_geo_mun.head()
# Out:
#    GEOCODIGO         MUNICIPIO  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
# 2    1301654           Guajará  AM     13  Norte  SUDOESTE AMAZONENSE
# 3    1200427   Rodrigues Alves  AC     12  Norte        VALE DO JURUA
# 4    1200203   Cruzeiro do Sul  AC     12  Norte        VALE DO JURUA
#
#         MICROREGIA LATITUDE LONGITUDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896
# 1    ALTO SOLIMOES   -4.372   -70.192
# 2            JURUA   -7.546   -72.584
# 3  CRUZEIRO DO SUL   -7.742   -72.647
# 4  CRUZEIRO DO SUL   -7.631    -72.67
#
#                                             geometry  AREA_1990  AREA_2020
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...       0.71       0.59
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...       0.95       0.39
# 2  POLYGON ((-73.73762 -7.13432, -73.70822 -7.040...       2.16       1.43
# 3  POLYGON ((-73.69158 -7.76778, -73.67485 -7.740...        NaN       0.43
# 4  POLYGON ((-73.62958 -8.05086, -73.42396 -8.032...       1.14       0.84

# %%
pam_cana_diff_geo_sp = pam_cana_diff_geo_mun[pam_cana_diff_geo_mun['UF'] == 'SP']
pam_cana_diff_geo_sp.to_file("../data/pam/output/cana/pam_cana_diff_geo_sp.geojson", driver='GeoJSON')
